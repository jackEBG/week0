# %%
import pandas as pd
import numpy as np
df=pd.read_csv("C:/Users/Admin.DESKTOP-M4R2VLU/Desktop/week01/week0/data/benin-malanville.csv")
numeric_columns = df.select_dtypes(include=['number']).columns

print("Summary Statistics:")
for column in numeric_columns:
    print(f"\nColumn: {column}")
    print(f"Mean: {df[column].mean():.2f}")
    print(f"Median: {df[column].median():.2f}")
    print(f"Standard Deviation: {df[column].std():.2f}")
    print(f"Minimum: {df[column].min():.2f}")
    print(f"Maximum: {df[column].max():.2f}")
    print(f"Variance: {df[column].var():.2f}")
    print(f"Skewness: {df[column].skew():.2f}")
    print(f"Kurtosis: {df[column].kurtosis():.2f}")
# Out:
# Summary Statistics:
#
# Column: GHI
# Mean: 240.56
# Median: 1.80
# Standard Deviation: 331.13
# Minimum: -12.90
# Maximum: 1413.00
# Variance: 109647.96
# Skewness: 1.03
# Kurtosis: -0.46
#
# Column: DNI
# Mean: 167.19
# Median: -0.10
# Standard Deviation: 261.71
# Minimum: -7.80
# Maximum: 952.30
# Variance: 68492.39
# Skewness: 1.29
# Kurtosis: 0.17
#
# Column: DHI
# Mean: 115.36
# Median: 1.60
# Standard Deviation: 158.69
# Minimum: -12.60
# Maximum: 759.20
# Variance: 25182.86
# Skewness: 1.21
# Kurtosis: 0.50
#
# Column: ModA
# Mean: 236.59
# Median: 4.50
# Standard Deviation: 326.89
# Minimum: 0.00
# Maximum: 1342.30
# Variance: 106860.25
# Skewness: 1.07
# Kurtosis: -0.39
#
# Column: ModB
# Mean: 228.88
# Median: 4.30
# Standard Deviation: 316.54
# Minimum: 0.00
# Maximum: 1342.30
# Variance: 100195.37
# Skewness: 1.08
# Kurtosis: -0.35
#
# Column: Tamb
# Mean: 28.18
# Median: 28.00
# Standard Deviation: 5.92
# Minimum: 11.00
# Maximum: 43.80
# Variance: 35.10
# Skewness: 0.00
# Kurtosis: -0.44
#
# Column: RH
# Mean: 54.49
# Median: 55.10
# Standard Deviation: 28.07
# Minimum: 2.10
# Maximum: 100.00
# Variance: 788.10
# Skewness: -0.03
# Kurtosis: -1.30
#
# Column: WS
# Mean: 2.12
# Median: 1.90
# Standard Deviation: 1.60
# Minimum: 0.00
# Maximum: 19.50
# Variance: 2.57
# Skewness: 0.87
# Kurtosis: 1.58
#
# Column: WSgust
# Mean: 2.81
# Median: 2.60
# Standard Deviation: 2.03
# Minimum: 0.00
# Maximum: 26.60
# Variance: 4.12
# Skewness: 0.93
# Kurtosis: 1.94
#
# Column: WSstdev
# Mean: 0.47
# Median: 0.50
# Standard Deviation: 0.27
# Minimum: 0.00
# Maximum: 4.20
# Variance: 0.07
# Skewness: 0.70
# Kurtosis: 3.35
#
# Column: WD
# Mean: 153.44
# Median: 181.00
# Standard Deviation: 102.33
# Minimum: 0.00
# Maximum: 360.00
# Variance: 10472.01
# Skewness: -0.08
# Kurtosis: -1.26
#
# Column: WDstdev
# Mean: 8.58
# Median: 8.60
# Standard Deviation: 6.39
# Minimum: 0.00
# Maximum: 99.40
# Variance: 40.78
# Skewness: 1.07
# Kurtosis: 4.65
#
# Column: BP
# Mean: 994.20
# Median: 994.00
# Standard Deviation: 2.47
# Minimum: 985.00
# Maximum: 1003.00
# Variance: 6.13
# Skewness: -0.26
# Kurtosis: -0.06
#
# Column: Cleaning
# Mean: 0.00
# Median: 0.00
# Standard Deviation: 0.03
# Minimum: 0.00
# Maximum: 1.00
# Variance: 0.00
# Skewness: 32.87
# Kurtosis: 1078.72
#
# Column: Precipitation
# Mean: 0.00
# Median: 0.00
# Standard Deviation: 0.04
# Minimum: 0.00
# Maximum: 2.50
# Variance: 0.00
# Skewness: 34.62
# Kurtosis: 1518.29
#
# Column: TModA
# Mean: 35.25
# Median: 30.00
# Standard Deviation: 14.81
# Minimum: 9.00
# Maximum: 81.00
# Variance: 219.25
# Skewness: 0.68
# Kurtosis: -0.58
#
# Column: TModB
# Mean: 32.47
# Median: 28.90
# Standard Deviation: 12.35
# Minimum: 8.10
# Maximum: 72.50
# Variance: 152.49
# Skewness: 0.62
# Kurtosis: -0.44
#
# Column: Comments
# Mean: nan
# Median: nan
# Standard Deviation: nan
# Minimum: nan
# Maximum: nan
# Variance: nan
# Skewness: nan
# Kurtosis: nan
# c:\Users\Admin.DESKTOP-M4R2VLU\Desktop\week01\week0\.venv\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1241: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
